# %%
# !pip install unsloth vllm
# !pip install --upgrade pillow
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: unsloth in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (2025.3.19)
# Requirement already satisfied: vllm in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (0.8.2)
# Requirement already satisfied: unsloth_zoo>=2025.3.17 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from unsloth) (2025.3.17)
# Requirement already satisfied: torch>=2.4.0 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from unsloth) (2.6.0)
# Requirement already satisfied: xformers>=0.0.27.post2 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from unsloth) (0.0.29.post2)
# Requirement already satisfied: bitsandbytes in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from unsloth) (0.45.2)
# Requirement already satisfied: triton>=3.0.0 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from unsloth) (3.1.0)
# Requirement already satisfied: packaging in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from unsloth) (24.2)
# Requirement already satisfied: tyro in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from unsloth) (0.9.18)
# Requirement already satisfied: transformers!=4.47.0,>=4.46.1 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from unsloth) (4.50.3)
# Requirement already satisfied: datasets>=2.16.0 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from unsloth) (3.2.0)
# Requirement already satisfied: sentencepiece>=0.2.0 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from unsloth) (0.2.0)
# Requirement already satisfied: tqdm in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from unsloth) (4.67.1)
# Requirement already satisfied: psutil in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from unsloth) (5.9.0)
# Requirement already satisfied: wheel>=0.42.0 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from unsloth) (0.44.0)
# Requirement already satisfied: numpy in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from unsloth) (1.26.4)
# Requirement already satisfied: accelerate>=0.34.1 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from unsloth) (1.2.1)
# Requirement already satisfied: trl!=0.15.0,!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,<=0.15.2,>=0.7.9 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from unsloth) (0.14.0)
# Requirement already satisfied: peft!=0.11.0,>=0.7.1 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from unsloth) (0.14.0)
# Requirement already satisfied: protobuf<4.0.0 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from unsloth) (3.20.3)
# Requirement already satisfied: huggingface_hub in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from unsloth) (0.29.3)
# Requirement already satisfied: hf_transfer in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from unsloth) (0.1.9)
# Requirement already satisfied: diffusers in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from unsloth) (0.32.2)
# Requirement already satisfied: torchvision in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from unsloth) (0.21.0)
# Requirement already satisfied: cachetools in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from vllm) (5.5.1)
# Requirement already satisfied: requests>=2.26.0 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from vllm) (2.32.3)
# Requirement already satisfied: blake3 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from vllm) (1.0.4)
# Requirement already satisfied: py-cpuinfo in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from vllm) (9.0.0)
# Requirement already satisfied: tokenizers>=0.19.1 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from vllm) (0.21.0)
# Requirement already satisfied: fastapi>=0.115.0 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from fastapi[standard]>=0.115.0->vllm) (0.115.11)
# Requirement already satisfied: aiohttp in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from vllm) (3.11.11)
# Requirement already satisfied: openai>=1.52.0 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from vllm) (1.68.2)
# Requirement already satisfied: pydantic>=2.9 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from vllm) (2.10.6)
# Requirement already satisfied: prometheus_client>=0.18.0 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from vllm) (0.21.1)
# Requirement already satisfied: pillow in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from vllm) (11.1.0)
# Requirement already satisfied: prometheus-fastapi-instrumentator>=7.0.0 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from vllm) (7.1.0)
# Requirement already satisfied: tiktoken>=0.6.0 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from vllm) (0.9.0)
# Requirement already satisfied: lm-format-enforcer<0.11,>=0.10.11 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from vllm) (0.10.11)
# Requirement already satisfied: llguidance<0.8.0,>=0.7.9 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from vllm) (0.7.11)
# Requirement already satisfied: outlines==0.1.11 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from vllm) (0.1.11)
# Requirement already satisfied: lark==1.2.2 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from vllm) (1.2.2)
# Requirement already satisfied: xgrammar==0.1.16 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from vllm) (0.1.16)
# Requirement already satisfied: typing_extensions>=4.10 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from vllm) (4.13.0)
# Requirement already satisfied: filelock>=3.16.1 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from vllm) (3.17.0)
# Requirement already satisfied: partial-json-parser in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from vllm) (0.2.1.1.post5)
# Requirement already satisfied: pyzmq in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from vllm) (26.2.0)
# Requirement already satisfied: msgspec in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from vllm) (0.19.0)
# Requirement already satisfied: gguf==0.10.0 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from vllm) (0.10.0)
# Requirement already satisfied: importlib_metadata in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from vllm) (8.6.1)
# Requirement already satisfied: mistral_common>=1.5.4 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from mistral_common[opencv]>=1.5.4->vllm) (1.5.4)
# Requirement already satisfied: pyyaml in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from vllm) (6.0.2)
# Requirement already satisfied: einops in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from vllm) (0.8.1)
# Requirement already satisfied: compressed-tensors==0.9.2 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from vllm) (0.9.2)
# Requirement already satisfied: depyf==0.18.0 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from vllm) (0.18.0)
# Requirement already satisfied: cloudpickle in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from vllm) (3.1.1)
# Requirement already satisfied: watchfiles in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from vllm) (1.0.4)
# Requirement already satisfied: python-json-logger in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from vllm) (3.3.0)
# Requirement already satisfied: scipy in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from vllm) (1.15.2)
# Requirement already satisfied: ninja in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from vllm) (1.11.1.4)
# Requirement already satisfied: numba==0.60.0 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from vllm) (0.60.0)
# Requirement already satisfied: ray>=2.43.0 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from ray[cgraph]>=2.43.0->vllm) (2.44.1)
# Requirement already satisfied: torchaudio==2.6.0 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from vllm) (2.6.0)
# Requirement already satisfied: astor in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from depyf==0.18.0->vllm) (0.8.1)
# Requirement already satisfied: dill in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from depyf==0.18.0->vllm) (0.3.8)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from numba==0.60.0->vllm) (0.43.0)
# Requirement already satisfied: interegular in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from outlines==0.1.11->vllm) (0.3.3)
# Requirement already satisfied: jinja2 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from outlines==0.1.11->vllm) (3.1.6)
# Requirement already satisfied: nest_asyncio in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from outlines==0.1.11->vllm) (1.6.0)
# Requirement already satisfied: diskcache in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from outlines==0.1.11->vllm) (5.6.3)
# Requirement already satisfied: referencing in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from outlines==0.1.11->vllm) (0.36.2)
# Requirement already satisfied: jsonschema in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from outlines==0.1.11->vllm) (4.23.0)
# Requirement already satisfied: pycountry in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from outlines==0.1.11->vllm) (24.6.1)
# Requirement already satisfied: airportsdata in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from outlines==0.1.11->vllm) (20250224)
# Requirement already satisfied: outlines_core==0.1.26 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from outlines==0.1.11->vllm) (0.1.26)
# Requirement already satisfied: networkx in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from torch>=2.4.0->unsloth) (3.4.2)
# Requirement already satisfied: fsspec in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from torch>=2.4.0->unsloth) (2024.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from torch>=2.4.0->unsloth) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from torch>=2.4.0->unsloth) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from torch>=2.4.0->unsloth) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from torch>=2.4.0->unsloth) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from torch>=2.4.0->unsloth) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from torch>=2.4.0->unsloth) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from torch>=2.4.0->unsloth) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from torch>=2.4.0->unsloth) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from torch>=2.4.0->unsloth) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from torch>=2.4.0->unsloth) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from torch>=2.4.0->unsloth) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from torch>=2.4.0->unsloth) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from torch>=2.4.0->unsloth) (12.4.127)
# Collecting triton>=3.0.0 (from unsloth)
#   Downloading triton-3.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: sympy==1.13.1 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from torch>=2.4.0->unsloth) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from sympy==1.13.1->torch>=2.4.0->unsloth) (1.3.0)
# Requirement already satisfied: safetensors>=0.4.3 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from accelerate>=0.34.1->unsloth) (0.5.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from datasets>=2.16.0->unsloth) (19.0.0)
# Requirement already satisfied: pandas in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from datasets>=2.16.0->unsloth) (2.2.3)
# Requirement already satisfied: xxhash in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from datasets>=2.16.0->unsloth) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from datasets>=2.16.0->unsloth) (0.70.16)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from fastapi>=0.115.0->fastapi[standard]>=0.115.0->vllm) (0.46.1)
# Requirement already satisfied: fastapi-cli>=0.0.5 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from fastapi-cli[standard]>=0.0.5; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (0.0.7)
# Requirement already satisfied: httpx>=0.23.0 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from fastapi[standard]>=0.115.0->vllm) (0.28.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from fastapi[standard]>=0.115.0->vllm) (0.0.20)
# Requirement already satisfied: email-validator>=2.0.0 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from fastapi[standard]>=0.115.0->vllm) (2.2.0)
# Requirement already satisfied: uvicorn>=0.12.0 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (0.34.0)
# Requirement already satisfied: opencv-python-headless>=4.0.0 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from mistral_common[opencv]>=1.5.4->vllm) (4.11.0.86)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from openai>=1.52.0->vllm) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from openai>=1.52.0->vllm) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from openai>=1.52.0->vllm) (0.9.0)
# Requirement already satisfied: sniffio in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from openai>=1.52.0->vllm) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from pydantic>=2.9->vllm) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from pydantic>=2.9->vllm) (2.27.2)
# Requirement already satisfied: click>=7.0 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from ray>=2.43.0->ray[cgraph]>=2.43.0->vllm) (8.1.8)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from ray>=2.43.0->ray[cgraph]>=2.43.0->vllm) (1.1.0)
# Requirement already satisfied: aiosignal in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from ray>=2.43.0->ray[cgraph]>=2.43.0->vllm) (1.3.2)
# Requirement already satisfied: frozenlist in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from ray>=2.43.0->ray[cgraph]>=2.43.0->vllm) (1.5.0)
# Requirement already satisfied: cupy-cuda12x in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from ray[cgraph]>=2.43.0->vllm) (13.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from requests>=2.26.0->vllm) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from requests>=2.26.0->vllm) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from requests>=2.26.0->vllm) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from requests>=2.26.0->vllm) (2024.12.14)
# Requirement already satisfied: regex>=2022.1.18 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from tiktoken>=0.6.0->vllm) (2024.11.6)
# Requirement already satisfied: rich in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from trl!=0.15.0,!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,<=0.15.2,>=0.7.9->unsloth) (13.9.4)
# Requirement already satisfied: cut_cross_entropy in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from unsloth_zoo>=2025.3.17->unsloth) (25.1.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from aiohttp->vllm) (2.4.4)
# Requirement already satisfied: attrs>=17.3.0 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from aiohttp->vllm) (24.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from aiohttp->vllm) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from aiohttp->vllm) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from aiohttp->vllm) (1.18.3)
# Requirement already satisfied: zipp>=3.20 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from importlib_metadata->vllm) (3.21.0)
# Requirement already satisfied: docstring-parser>=0.15 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from tyro->unsloth) (0.16)
# Requirement already satisfied: shtab>=1.5.6 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from tyro->unsloth) (1.7.1)
# Requirement already satisfied: typeguard>=4.0.0 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from tyro->unsloth) (4.4.2)
# Requirement already satisfied: dnspython>=2.0.0 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from email-validator>=2.0.0->fastapi[standard]>=0.115.0->vllm) (2.7.0)
# Requirement already satisfied: typer>=0.12.3 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from fastapi-cli>=0.0.5->fastapi-cli[standard]>=0.0.5; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (0.15.2)
# Requirement already satisfied: rich-toolkit>=0.11.1 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from fastapi-cli>=0.0.5->fastapi-cli[standard]>=0.0.5; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (0.14.0)
# Requirement already satisfied: httpcore==1.* in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from httpx>=0.23.0->fastapi[standard]>=0.115.0->vllm) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.23.0->fastapi[standard]>=0.115.0->vllm) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from jinja2->outlines==0.1.11->vllm) (2.1.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from jsonschema->outlines==0.1.11->vllm) (2024.10.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from jsonschema->outlines==0.1.11->vllm) (0.23.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from rich->trl!=0.15.0,!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,<=0.15.2,>=0.7.9->unsloth) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from rich->trl!=0.15.0,!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,<=0.15.2,>=0.7.9->unsloth) (2.19.1)
# Requirement already satisfied: httptools>=0.6.3 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (1.0.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (0.21.0)
# Requirement already satisfied: websockets>=10.4 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (15.0.1)
# Requirement already satisfied: fastrlock>=0.5 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from cupy-cuda12x->ray[cgraph]>=2.43.0->vllm) (0.8.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from pandas->datasets>=2.16.0->unsloth) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from pandas->datasets>=2.16.0->unsloth) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from pandas->datasets>=2.16.0->unsloth) (2025.1)
# Requirement already satisfied: mdurl~=0.1 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->trl!=0.15.0,!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,<=0.15.2,>=0.7.9->unsloth) (0.1.2)
# Requirement already satisfied: six>=1.5 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.16.0->unsloth) (1.17.0)
# Requirement already satisfied: shellingham>=1.3.0 in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (from typer>=0.12.3->fastapi-cli>=0.0.5->fastapi-cli[standard]>=0.0.5; extra == "standard"->fastapi[standard]>=0.115.0->vllm) (1.5.4)
# Downloading triton-3.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (253.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.2/253.2 MB 26.7 MB/s eta 0:00:000:00:01m eta 0:00:01
# Installing collected packages: triton
#   Attempting uninstall: triton
#     Found existing installation: triton 3.1.0
#     Uninstalling triton-3.1.0:
#       Successfully uninstalled triton-3.1.0
# Successfully installed triton-3.2.0
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: pillow in /home/nurbot/miniconda3/envs/smol/lib/python3.11/site-packages (11.1.0)

# %%
from unsloth import FastLanguageModel
import torch

max_seq_length = 1024  # Can increase for longer reasoning traces
lora_rank = 32  # Larger rank = smarter, but slower

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name="google/gemma-3-1b-it",
    max_seq_length=max_seq_length,
    load_in_4bit=True,  # False for LoRA 16bit
    fast_inference=True,  # Enable vLLM fast inference
    max_lora_rank=lora_rank,
    gpu_memory_utilization=0.6,  # Reduce if out of memory
)

model = FastLanguageModel.get_peft_model(
    model,
    r=lora_rank,  # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules=[
        "q_proj",
        "k_proj",
        "v_proj",
        "o_proj",
        "gate_proj",
        "up_proj",
        "down_proj",
    ],  # Remove QKVO if out of memory
    lora_alpha=lora_rank,
    use_gradient_checkpointing="unsloth",  # Enable long context finetuning
    random_state=3407,
)

# Define the system prompt that instructs the model to use a specific format
SYSTEM_PROMPT = """
Respond in the following format:
<reasoning>
...
</reasoning>
<answer>
...
</answer>
"""

XML_COT_FORMAT = """\
<reasoning>
{reasoning}
</reasoning>
<answer>
{answer}
</answer>
"""
# Out:
# /tmp/ipykernel_19785/107621736.py:1: UserWarning: WARNING: Unsloth should be imported before transformers to ensure all optimizations are applied. Your code may run slower or encounter memory issues without these optimizations.
#
# Please restructure your imports with 'import unsloth' at the top of your file.
#   from unsloth import FastLanguageModel
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 2025-03-28 22:08:37.851756: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743196117.863070   19785 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743196117.866649   19785 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1743196117.876188   19785 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743196117.876197   19785 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743196117.876198   19785 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743196117.876199   19785 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-03-28 22:08:37.879641: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# INFO 03-28 22:08:50 [__init__.py:239] Automatically detected platform cuda.
# ==((====))==  Unsloth 2025.3.19: Fast Gemma3 patching. Transformers: 4.50.3. vLLM: 0.8.2.
#    \\   /|    NVIDIA RTX 6000 Ada Generation. Num GPUs = 4. Max memory: 47.408 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.6.0+cu124. CUDA: 8.9. CUDA Toolkit: 12.4. Triton: 3.2.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.29.post2. FA2 = True]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth: Making `model.base_model.model.model` require gradients

# %%
import re
from datasets import load_dataset, Dataset


# Helper functions to extract answers from different formats
def extract_xml_answer(text: str) -> str:
    answer = text.split("<answer>")[-1]
    answer = answer.split("</answer>")[0]
    return answer.strip()


def extract_hash_answer(text: str) -> str | None:
    if "####" not in text:
        return None
    return text.split("####")[1].strip()


# Function to prepare the GSM8K dataset
def get_gsm8k_questions(split="train") -> Dataset:
    data = load_dataset("openai/gsm8k", "main")[split]
    data = data.map(
        lambda x: {
            "prompt": [
                {"role": "system", "content": SYSTEM_PROMPT},
                {"role": "user", "content": x["question"]},
            ],
            "answer": extract_hash_answer(x["answer"]),
        }
    )
    return data


dataset = get_gsm8k_questions()

# %%
# Reward function that checks if the answer is correct
def correctness_reward_func(prompts, completions, answer, **kwargs) -> list[float]:
    responses = [completion[0]["content"] for completion in completions]
    q = prompts[0][-1]["content"]
    extracted_responses = [extract_xml_answer(r) for r in responses]
    print(
        "-" * 20,
        f"Question:\n{q}",
        f"\nAnswer:\n{answer[0]}",
        f"\nResponse:\n{responses[0]}",
        f"\nExtracted:\n{extracted_responses[0]}",
    )
    return [2.0 if r == a else 0.0 for r, a in zip(extracted_responses, answer)]


# Reward function that checks if the answer is an integer
def int_reward_func(completions, **kwargs) -> list[float]:
    responses = [completion[0]["content"] for completion in completions]
    extracted_responses = [extract_xml_answer(r) for r in responses]
    return [0.5 if r.isdigit() else 0.0 for r in extracted_responses]


# Reward function that checks if the completion follows the strict format
def strict_format_reward_func(completions, **kwargs) -> list[float]:
    pattern = r"^<reasoning>\n.*?\n</reasoning>\n<answer>\n.*?\n</answer>\n$"
    responses = [completion[0]["content"] for completion in completions]
    matches = [re.match(pattern, r) for r in responses]
    return [0.5 if match else 0.0 for match in matches]


# Reward function that checks if the completion follows a more relaxed format
def soft_format_reward_func(completions, **kwargs) -> list[float]:
    pattern = r"<reasoning>.*?</reasoning>\s*<answer>.*?</answer>"
    responses = [completion[0]["content"] for completion in completions]
    matches = [re.match(pattern, r) for r in responses]
    return [0.5 if match else 0.0 for match in matches]


# Reward function that counts XML tags and penalizes extra content
def count_xml(text) -> float:
    count = 0.0
    if text.count("<reasoning>\n") == 1:
        count += 0.125
    if text.count("\n</reasoning>\n") == 1:
        count += 0.125
    if text.count("\n<answer>\n") == 1:
        count += 0.125
        count -= len(text.split("\n</answer>\n")[-1]) * 0.001
    if text.count("\n</answer>") == 1:
        count += 0.125
        count -= (len(text.split("\n</answer>")[-1]) - 1) * 0.001
    return count


def xmlcount_reward_func(completions, **kwargs) -> list[float]:
    contents = [completion[0]["content"] for completion in completions]
    return [count_xml(c) for c in contents]

# %%
from trl import GRPOConfig, GRPOTrainer

max_prompt_length = 256

training_args = GRPOConfig(
    learning_rate=5e-6,
    adam_beta1=0.9,
    adam_beta2=0.99,
    weight_decay=0.1,
    warmup_ratio=0.1,
    lr_scheduler_type="cosine",
    optim="paged_adamw_8bit",
    logging_steps=1,
    per_device_train_batch_size=1,
    gradient_accumulation_steps=1,  # Increase to 4 for smoother training
    num_generations=6,  # Decrease if out of memory
    max_prompt_length=max_prompt_length,
    max_completion_length=max_seq_length - max_prompt_length,
    # num_train_epochs = 1, # Set to 1 for a full training run
    max_steps=250,
    save_steps=250,
    max_grad_norm=0.1,
    report_to="none",  # Can use Weights & Biases
    output_dir="outputs",
)

trainer = GRPOTrainer(
    model=model,
    processing_class=tokenizer,
    data_collator=custom_data_collator,  # Add this line
    reward_funcs=[
        xmlcount_reward_func,
        soft_format_reward_func,
        strict_format_reward_func,
        int_reward_func,
        correctness_reward_func,
    ],
    args=training_args,
    train_dataset=processed_dataset,
)

trainer.train()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 27
#       3 max_prompt_length = 256
#       5 training_args = GRPOConfig(
#       6     learning_rate=5e-6,
#       7     adam_beta1=0.9,
#    (...)
#      24     output_dir="outputs",
#      25 )
# ---> 27 trainer = GRPOTrainer(
#      28     model=model,
#      29     processing_class=tokenizer,
#      30     data_collator=custom_data_collator,  # Add this line
#      31     reward_funcs=[
#      32         xmlcount_reward_func,
#      33         soft_format_reward_func,
#      34         strict_format_reward_func,
#      35         int_reward_func,
#      36         correctness_reward_func,
#      37     ],
#      38     args=training_args,
#      39     train_dataset=processed_dataset,
#      40 )
#      42 trainer.train()
#
# File ~/miniconda3/envs/smol/lib/python3.11/site-packages/unsloth/trainer.py:197, in _backwards_compatible_trainer.<locals>.new_init(self, *args, **kwargs)
#     194 config_dict.update(additional_config_kwargs)
#     196 # Create Config with all the collected parameters
# --> 197 config = config_class(**config_dict)
#     199 # Reconstruct kwargs for Trainer
#     200 kwargs = trainer_kwargs
#
# File ~/ws/gist/notebooks/grpo-playground/unsloth_compiled_cache/UnslothGRPOTrainer.py:487, in UnslothGRPOConfig.__init__(self, output_dir, overwrite_output_dir, do_train, do_eval, do_predict, eval_strategy, prediction_loss_only, per_device_train_batch_size, per_device_eval_batch_size, per_gpu_train_batch_size, per_gpu_eval_batch_size, gradient_accumulation_steps, eval_accumulation_steps, eval_delay, torch_empty_cache_steps, learning_rate, weight_decay, adam_beta1, adam_beta2, adam_epsilon, max_grad_norm, num_train_epochs, max_steps, lr_scheduler_type, warmup_ratio, warmup_steps, log_level, log_level_replica, log_on_each_node, logging_dir, logging_strategy, logging_first_step, logging_steps, logging_nan_inf_filter, save_strategy, save_steps, save_total_limit, save_safetensors, save_on_each_node, save_only_model, restore_callback_states_from_checkpoint, no_cuda, use_cpu, use_mps_device, seed, data_seed, jit_mode_eval, use_ipex, bf16, fp16, fp16_opt_level, half_precision_backend, bf16_full_eval, fp16_full_eval, tf32, local_rank, ddp_backend, tpu_num_cores, tpu_metrics_debug, debug, dataloader_drop_last, eval_steps, dataloader_num_workers, dataloader_prefetch_factor, past_index, run_name, disable_tqdm, remove_unused_columns, label_names, load_best_model_at_end, metric_for_best_model, greater_is_better, ignore_data_skip, fsdp, fsdp_min_num_params, fsdp_config, tp_size, fsdp_transformer_layer_cls_to_wrap, accelerator_config, deepspeed, label_smoothing_factor, optim, optim_args, adafactor, group_by_length, length_column_name, report_to, ddp_find_unused_parameters, ddp_bucket_cap_mb, ddp_broadcast_buffers, dataloader_pin_memory, dataloader_persistent_workers, skip_memory_metrics, use_legacy_prediction_loop, push_to_hub, resume_from_checkpoint, hub_model_id, hub_strategy, hub_token, hub_private_repo, hub_always_push, gradient_checkpointing, gradient_checkpointing_kwargs, include_inputs_for_metrics, eval_do_concat_batches, fp16_backend, evaluation_strategy, push_to_hub_model_id, push_to_hub_organization, push_to_hub_token, mp_parameters, auto_find_batch_size, full_determinism, torchdynamo, ray_scope, ddp_timeout, torch_compile, torch_compile_backend, torch_compile_mode, dispatch_batches, split_batches, include_tokens_per_second, include_num_input_tokens_seen, neftune_noise_alpha, optim_target_modules, batch_eval_metrics, eval_on_start, use_liger_kernel, eval_use_gather_object, average_tokens_across_devices, model_init_kwargs, max_prompt_length, num_generations, temperature, max_completion_length, use_vllm, vllm_device, vllm_gpu_memory_utilization, beta, vllm_sampling_params, unsloth_num_chunks, **kwargs)
#     484     output_dir = 'unsloth_training_checkpoints'
#     485     save_strategy = 'no'
# --> 487 super().__init__(
#     488     output_dir = output_dir,
#     489     overwrite_output_dir = overwrite_output_dir,
#     490     do_train = do_train,
#     491     do_eval = do_eval,
#     492     do_predict = do_predict,
#     493     eval_strategy = eval_strategy,
#     494     prediction_loss_only = prediction_loss_only,
#     495     per_device_train_batch_size = per_device_train_batch_size,
#     496     per_device_eval_batch_size = per_device_eval_batch_size,
#     497     per_gpu_train_batch_size = per_gpu_train_batch_size,
#     498     per_gpu_eval_batch_size = per_gpu_eval_batch_size,
#     499     gradient_accumulation_steps = gradient_accumulation_steps,
#     500     eval_accumulation_steps = eval_accumulation_steps,
#     501     eval_delay = eval_delay,
#     502     torch_empty_cache_steps = torch_empty_cache_steps,
#     503     learning_rate = learning_rate,
#     504     weight_decay = weight_decay,
#     505     adam_beta1 = adam_beta1,
#     506     adam_beta2 = adam_beta2,
#     507     adam_epsilon = adam_epsilon,
#     508     max_grad_norm = max_grad_norm,
#     509     num_train_epochs = num_train_epochs,
#     510     max_steps = max_steps,
#     511     lr_scheduler_type = lr_scheduler_type,
#     512     warmup_ratio = warmup_ratio,
#     513     warmup_steps = warmup_steps,
#     514     log_level = log_level,
#     515     log_level_replica = log_level_replica,
#     516     log_on_each_node = log_on_each_node,
#     517     logging_dir = logging_dir,
#     518     logging_strategy = logging_strategy,
#     519     logging_first_step = logging_first_step,
#     520     logging_steps = logging_steps,
#     521     logging_nan_inf_filter = logging_nan_inf_filter,
#     522     save_strategy = save_strategy,
#     523     save_steps = save_steps,
#     524     save_total_limit = save_total_limit,
#     525     save_safetensors = save_safetensors,
#     526     save_on_each_node = save_on_each_node,
#     527     save_only_model = save_only_model,
#     528     restore_callback_states_from_checkpoint = restore_callback_states_from_checkpoint,
#     529     no_cuda = no_cuda,
#     530     use_cpu = use_cpu,
#     531     use_mps_device = use_mps_device,
#     532     seed = seed,
#     533     data_seed = data_seed,
#     534     jit_mode_eval = jit_mode_eval,
#     535     use_ipex = use_ipex,
#     536     bf16 = bf16,
#     537     fp16 = fp16,
#     538     fp16_opt_level = fp16_opt_level,
#     539     half_precision_backend = half_precision_backend,
#     540     bf16_full_eval = bf16_full_eval,
#     541     fp16_full_eval = fp16_full_eval,
#     542     tf32 = tf32,
#     543     local_rank = local_rank,
#     544     ddp_backend = ddp_backend,
#     545     tpu_num_cores = tpu_num_cores,
#     546     tpu_metrics_debug = tpu_metrics_debug,
#     547     debug = debug,
#     548     dataloader_drop_last = dataloader_drop_last,
#     549     eval_steps = eval_steps,
#     550     dataloader_num_workers = dataloader_num_workers,
#     551     dataloader_prefetch_factor = dataloader_prefetch_factor,
#     552     past_index = past_index,
#     553     run_name = run_name,
#     554     disable_tqdm = disable_tqdm,
#     555     remove_unused_columns = remove_unused_columns,
#     556     label_names = label_names,
#     557     load_best_model_at_end = load_best_model_at_end,
#     558     metric_for_best_model = metric_for_best_model,
#     559     greater_is_better = greater_is_better,
#     560     ignore_data_skip = ignore_data_skip,
#     561     fsdp = fsdp,
#     562     fsdp_min_num_params = fsdp_min_num_params,
#     563     fsdp_config = fsdp_config,
#     564     tp_size = tp_size,
#     565     fsdp_transformer_layer_cls_to_wrap = fsdp_transformer_layer_cls_to_wrap,
#     566     accelerator_config = accelerator_config,
#     567     deepspeed = deepspeed,
#     568     label_smoothing_factor = label_smoothing_factor,
#     569     optim = optim,
#     570     optim_args = optim_args,
#     571     adafactor = adafactor,
#     572     group_by_length = group_by_length,
#     573     length_column_name = length_column_name,
#     574     report_to = report_to,
#     575     ddp_find_unused_parameters = ddp_find_unused_parameters,
#     576     ddp_bucket_cap_mb = ddp_bucket_cap_mb,
#     577     ddp_broadcast_buffers = ddp_broadcast_buffers,
#     578     dataloader_pin_memory = dataloader_pin_memory,
#     579     dataloader_persistent_workers = dataloader_persistent_workers,
#     580     skip_memory_metrics = skip_memory_metrics,
#     581     use_legacy_prediction_loop = use_legacy_prediction_loop,
#     582     push_to_hub = push_to_hub,
#     583     resume_from_checkpoint = resume_from_checkpoint,
#     584     hub_model_id = hub_model_id,
#     585     hub_strategy = hub_strategy,
#     586     hub_token = hub_token,
#     587     hub_private_repo = hub_private_repo,
#     588     hub_always_push = hub_always_push,
#     589     gradient_checkpointing = gradient_checkpointing,
#     590     gradient_checkpointing_kwargs = gradient_checkpointing_kwargs,
#     591     include_inputs_for_metrics = include_inputs_for_metrics,
#     592     eval_do_concat_batches = eval_do_concat_batches,
#     593     fp16_backend = fp16_backend,
#     594     evaluation_strategy = evaluation_strategy,
#     595     push_to_hub_model_id = push_to_hub_model_id,
#     596     push_to_hub_organization = push_to_hub_organization,
#     597     push_to_hub_token = push_to_hub_token,
#     598     mp_parameters = mp_parameters,
#     599     auto_find_batch_size = auto_find_batch_size,
#     600     full_determinism = full_determinism,
#     601     torchdynamo = torchdynamo,
#     602     ray_scope = ray_scope,
#     603     ddp_timeout = ddp_timeout,
#     604     torch_compile = torch_compile,
#     605     torch_compile_backend = torch_compile_backend,
#     606     torch_compile_mode = torch_compile_mode,
#     607     dispatch_batches = dispatch_batches,
#     608     split_batches = split_batches,
#     609     include_tokens_per_second = include_tokens_per_second,
#     610     include_num_input_tokens_seen = include_num_input_tokens_seen,
#     611     neftune_noise_alpha = neftune_noise_alpha,
#     612     optim_target_modules = optim_target_modules,
#     613     batch_eval_metrics = batch_eval_metrics,
#     614     eval_on_start = eval_on_start,
#     615     use_liger_kernel = use_liger_kernel,
#     616     eval_use_gather_object = eval_use_gather_object,
#     617     average_tokens_across_devices = average_tokens_across_devices,
#     618     model_init_kwargs = model_init_kwargs,
#     619     max_prompt_length = max_prompt_length,
#     620     num_generations = num_generations,
#     621     temperature = temperature,
#     622     max_completion_length = max_completion_length,
#     623     use_vllm = use_vllm,
#     624     vllm_device = vllm_device,
#     625     vllm_gpu_memory_utilization = vllm_gpu_memory_utilization,
#     626     beta = beta,**kwargs)
#     627 self.vllm_sampling_params = vllm_sampling_params
#     628 self.unsloth_num_chunks = unsloth_num_chunks
#
# TypeError: GRPOConfig.__init__() got an unexpected keyword argument 'data_collator'
